# %%
#Three lines to make our compiler able to draw:
import sys
import matplotlib

import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1,1,1,1,1,1,0.86,0.75,0.67,0.6,0.55,0.5])

xpoints = np.array([0.1667,0.3333,0.5,0.6667,0.8883,1,1,1,1,1,1,1])

# %%
plt.plot(xpoints, ypoints, marker='o')  # Scatter plot with markers
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision - Recall Curve')
plt.grid(True)
plt.show()
